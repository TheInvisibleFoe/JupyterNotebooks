# %% [markdown]
# # Double Slit Diffraction

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
r = 3000
t=2500

# %%
drun1 = pd.read_csv("csvinitdoubleslit.csv",usecols= [1,5],header = 0).dropna()
drun1light =[drun1['Run #1.1'][i] for i in range(r,len(drun1['Run #1.1'])-t) ]
drun1pos = [drun1['Run #1.5'][i] for i in range(r,len(drun1['Run #1.5'])-t) ]

# %%
fig,axes = plt.subplots(figsize=(16,9),nrows=1,ncols=1,squeeze=False)
axes[0][0].plot(drun1pos,drun1light)
axes[0][0].tick_params(axis='both',which='both',labelleft = False,left =False,right = False,bottom=False,top=False,labelbottom=False)

# %%
r1 = 0 
t1 = 0 
run1 = pd.read_csv("csvsingleslit.csv",usecols=[9,13],header = 0).dropna()
run1
# Out:
#                  Run #3.1      Run #3.5
# 0     Light Intensity (%)  Position (m)
# 1                     5.2     4.1667E-4
# 2                     5.2     4.1667E-4
# 3                     5.2     4.1667E-4
# 4                     5.3     4.1667E-4
# ...                   ...           ...
# 8531                  5.0       -5.2246
# 8532                  5.0       -5.2246
# 8533                  5.0       -5.2246
# 8534                  5.0       -5.2246
# 8535                  5.0       -5.2246
#
# [8536 rows x 2 columns]

# %%
run1light =[run1['Run #3.1'][i] for i in range(r1,len(run1['Run #3.1'])-t1) ]
run1pos = [run1['Run #3.5'][i] for i in range(r1,len(run1['Run #3.5'])-t1) ]

# %%
fig,axes = plt.subplots(figsize=(16,9),nrows=1,ncols=1,squeeze=False)
axes[0][0].plot(run1pos,run1light)
axes[0][0].tick_params(axis='both',which='both',labelleft = False,left =False,right = False,bottom=False,top=False,labelbottom=False)
